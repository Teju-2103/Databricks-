# %%
data = [(1,'databricks'),(2,'pyspark')]
schema= "id int,name string"
df = spark.createDataFrame(data,schema)
display(df)

# %%
data2 = [(1,'databricks'),(2,'pyspark')]
schema= "id int,name string"
df2 = spark.createDataFrame(data2,schema)
display(df2)
